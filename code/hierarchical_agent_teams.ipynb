# %% [markdown]
# # Hierarchical Agent Teams
#
# In our previous example ([Agent Supervisor](../agent_supervisor)), we introduced the concept of a single supervisor node to route work between different worker nodes.
#
# But what if the job for a single worker becomes too complex? What if the number of workers becomes too large?
#
# For some applications, the system may be more effective if work is distributed _hierarchically_.
#
# You can do this by composing different subgraphs and creating a top-level supervisor, along with mid-level supervisors.
#
# To do this, let's build a simple research assistant! The graph will look something like the following:
#
# ![diagram](attachment:50a6ed47-ace3-428e-8dcf-a13ec56c11d6.png)
#
# This notebook is inspired by the paper [AutoGen: Enabling Next-Gen LLM Applications via Multi-Agent Conversation](https://arxiv.org/abs/2308.08155), by Wu, et. al. In the rest of this notebook, you will:
#
# 1. Define the agents' tools to access the web and write files
# 2. Define some utilities to help create the graph and agents
# 3. Create and define each team (web research + doc writing)
# 4. Compose everything together.
#
# ## Setup
#
# First, let's install our required packages and set our API keys

# %%
# %% capture --no-stderr
# %pip install -U langgraph langchain langchain_openai langchain_experimental
# Out:
# UsageError: Cell magic `%%` not found.

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %% [markdown]
# <div class="admonition tip">
#     <p class="admonition-title">Set up <a href="https://smith.langchain.com">LangSmith</a> for LangGraph development</p>
#     <p style="padding-top: 5px;">
#         Sign up for LangSmith to quickly spot issues and improve the performance of your LangGraph projects. LangSmith lets you use trace data to debug, test, and monitor your LLM apps built with LangGraph — read more about how to get started <a href="https://docs.smith.langchain.com">here</a>.
#     </p>
# </div>

# %% [markdown]
# ## Create Tools
#
# Each team will be composed of one or more agents each with one or more tools. Below, define all the tools to be used by your different teams.
#
# We'll start with the research team.
#
# **ResearchTeam tools**
#
# The research team can use a search engine and url scraper to find information on the web. Feel free to add additional functionality below to boost the team performance!

# %%
from typing import Annotated, List

from langchain_community.document_loaders import WebBaseLoader
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool

tavily_tool = TavilySearchResults(max_results=5)


@tool
def scrape_webpages(urls: List[str]) -> str:
    """Use requests and bs4 to scrape the provided web pages for detailed information."""
    loader = WebBaseLoader(urls)
    docs = loader.load()
    return "\n\n".join(
        [
            f'<Document name="{doc.metadata.get("title", "")}">\n{doc.page_content}\n</Document>'
            for doc in docs
        ]
    )

# %% [markdown]
# **Document writing team tools**
#
# Next up, we will give some tools for the doc writing team to use.
# We define some bare-bones file-access tools below.
#
# Note that this gives the agents access to your file-system, which can be unsafe. We also haven't optimized the tool descriptions for performance.

# %%
from pathlib import Path
from tempfile import TemporaryDirectory
from typing import Dict, Optional

from langchain_experimental.utilities import PythonREPL
from typing_extensions import TypedDict

_TEMP_DIRECTORY = TemporaryDirectory()
WORKING_DIRECTORY = Path(_TEMP_DIRECTORY.name)


@tool
def create_outline(
    points: Annotated[List[str], "List of main points or sections."],
    file_name: Annotated[str, "File path to save the outline."],
) -> Annotated[str, "Path of the saved outline file."]:
    """Create and save an outline."""
    with (WORKING_DIRECTORY / file_name).open("w") as file:
        for i, point in enumerate(points):
            file.write(f"{i + 1}. {point}\n")
    return f"Outline saved to {file_name}"


@tool
def read_document(
    file_name: Annotated[str, "File path to save the document."],
    start: Annotated[Optional[int], "The start line. Default is 0"] = None,
    end: Annotated[Optional[int], "The end line. Default is None"] = None,
) -> str:
    """Read the specified document."""
    with (WORKING_DIRECTORY / file_name).open("r") as file:
        lines = file.readlines()
    if start is not None:
        start = 0
    return "\n".join(lines[start:end])


@tool
def write_document(
    content: Annotated[str, "Text content to be written into the document."],
    file_name: Annotated[str, "File path to save the document."],
) -> Annotated[str, "Path of the saved document file."]:
    """Create and save a text document."""
    with (WORKING_DIRECTORY / file_name).open("w") as file:
        file.write(content)
    return f"Document saved to {file_name}"


@tool
def edit_document(
    file_name: Annotated[str, "Path of the document to be edited."],
    inserts: Annotated[
        Dict[int, str],
        "Dictionary where key is the line number (1-indexed) and value is the text to be inserted at that line.",
    ],
) -> Annotated[str, "Path of the edited document file."]:
    """Edit a document by inserting text at specific line numbers."""

    with (WORKING_DIRECTORY / file_name).open("r") as file:
        lines = file.readlines()

    sorted_inserts = sorted(inserts.items())

    for line_number, text in sorted_inserts:
        if 1 <= line_number <= len(lines) + 1:
            lines.insert(line_number - 1, text + "\n")
        else:
            return f"Error: Line number {line_number} is out of range."

    with (WORKING_DIRECTORY / file_name).open("w") as file:
        file.writelines(lines)

    return f"Document edited and saved to {file_name}"


# Warning: This executes code locally, which can be unsafe when not sandboxed

repl = PythonREPL()


@tool
def python_repl(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    return f"Successfully executed:\n```python\n{code}\n```\nStdout: {result}"

# %% [markdown]
# ## Helper Utilities
#
# We are going to create a few utility functions to make it more concise when we want to:
#
# 1. Create a worker agent.
# 2. Create a supervisor for the sub-graph.
#
# These will simplify the graph compositional code at the end for us so it's easier to see what's going on.

# %%
from typing import List, Optional
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import AzureChatOpenAI

from langgraph.graph import END, StateGraph, START
from langchain_core.messages import HumanMessage


def agent_node(state, agent, name):
    result = agent.invoke(state)
    return {"messages": [HumanMessage(content=result["messages"][-1].content, name=name)]}


def create_team_supervisor(llm: AzureChatOpenAI, system_prompt, members) -> str:
    """An LLM-based router."""
    options = ["FINISH"] + members
    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
            },
            "required": ["next"],
        },
    }
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            MessagesPlaceholder(variable_name="messages"),
            (
                "system",
                "Given the conversation above, who should act next?"
                " Or should we FINISH? Select one of: {options}",
            ),
        ]
    ).partial(options=str(options), team_members=", ".join(members))
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        | JsonOutputFunctionsParser()
    )

# %% [markdown]
# ## Define Agent Teams
#
# Now we can get to define our hierarchical teams. "Choose your player!"
#
# ### Research Team
#
# The research team will have a search agent and a web scraping "research_agent" as the two worker nodes. Let's create those, as well as the team supervisor.

# %%
import functools
import operator

from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai.chat_models import AzureChatOpenAI
from langgraph.prebuilt import create_react_agent

# ResearchTeam graph state
class ResearchTeamState(TypedDict):
    # A message is added after each team member finishes
    messages: Annotated[List[BaseMessage], operator.add]
    # The team members are tracked so they are aware of
    # the others' skill-sets
    team_members: List[str]
    # Used to route work. The supervisor calls a function
    # that will update this every time it makes a decision
    next: str



llm = AzureChatOpenAI(
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

search_agent = create_react_agent(llm, tools=[tavily_tool])
search_node = functools.partial(agent_node, agent=search_agent, name="Search")

research_agent = create_react_agent(llm, tools=[scrape_webpages])
research_node = functools.partial(agent_node, agent=research_agent, name="WebScraper")

supervisor_agent = create_team_supervisor(
    llm,
    "You are a supervisor tasked with managing a conversation between the"
    " following workers:  Search, WebScraper. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH.",
    ["Search", "WebScraper"],
)

# %% [markdown]
# Now that we've created the necessary components, defining their interactions is easy. Add the nodes to the team graph, and define the edges, which determine the transition criteria.

# %%
research_graph = StateGraph(ResearchTeamState)
research_graph.add_node("Search", search_node)
research_graph.add_node("WebScraper", research_node)
research_graph.add_node("supervisor", supervisor_agent)

# Define the control flow
research_graph.add_edge("Search", "supervisor")
research_graph.add_edge("WebScraper", "supervisor")
research_graph.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {"Search": "Search", "WebScraper": "WebScraper", "FINISH": END},
)


research_graph.add_edge(START, "supervisor")
chain = research_graph.compile()


# The following functions interoperate between the top level graph state
# and the state of the research sub-graph
# this makes it so that the states of each graph don't get intermixed
def enter_chain(message: str):
    results = {
        "messages": [HumanMessage(content=message)],
    }
    return results


research_chain = enter_chain | chain

# %%
from IPython.display import Image, display

display(Image(chain.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# We can give this team work directly. Try it out below.

# %%
for s in research_chain.stream(
    "when is Taylor Swift's next tour?", {"recursion_limit": 100}
):
    if "__end__" not in s:
        print(s)
        print("---")
# Out:
# {'supervisor': {'next': 'Search'}}
# ---
# {'Search': {'messages': [HumanMessage(content='Taylor Swift\'s next tour is the "Eras Tour," which began in the U.S. in March 2023 and runs into August 2023. The tour features U.S. stadium dates, with international dates set to be revealed later. For more specific dates and locations, you can refer to detailed tour announcements and ticketing websites.', additional_kwargs={}, response_metadata={}, name='Search')]}}
# ---
# {'supervisor': {'next': 'WebScraper'}}
# ---
# {'WebScraper': {'messages': [HumanMessage(content="It appears that I am currently unable to scrape the web page directly for the information. However, you can visit Taylor Swift's official website [TaylorSwift.com](https://www.taylorswift.com/events) to get the most accurate and up-to-date information on her tour dates and locations.", additional_kwargs={}, response_metadata={}, name='WebScraper')]}}
# ---
# {'supervisor': {'next': 'FINISH'}}
# ---

# %% [markdown]
# ### Document Writing Team
#
# Create the document writing team below using a similar approach. This time, we will give each agent access to different file-writing tools.
#
# Note that we are giving file-system access to our agent here, which is not safe in all cases.

# %%
import operator
from pathlib import Path


# Document writing team graph state
class DocWritingState(TypedDict):
    # This tracks the team's conversation internally
    messages: Annotated[List[BaseMessage], operator.add]
    # This provides each worker with context on the others' skill sets
    team_members: str
    # This is how the supervisor tells langgraph who to work next
    next: str
    # This tracks the shared directory state
    current_files: str


# This will be run before each worker agent begins work
# It makes it so they are more aware of the current state
# of the working directory.
def prelude(state):
    written_files = []
    if not WORKING_DIRECTORY.exists():
        WORKING_DIRECTORY.mkdir()
    try:
        written_files = [
            f.relative_to(WORKING_DIRECTORY) for f in WORKING_DIRECTORY.rglob("*")
        ]
    except Exception:
        pass
    if not written_files:
        return {**state, "current_files": "No files written."}
    return {
        **state,
        "current_files": "\nBelow are files your team has written to the directory:\n"
        + "\n".join([f" - {f}" for f in written_files]),
    }



llm = AzureChatOpenAI(
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

doc_writer_agent = create_react_agent(llm, tools=[write_document, edit_document, read_document])
# Injects current directory working state before each call
context_aware_doc_writer_agent = prelude | doc_writer_agent
doc_writing_node = functools.partial(
    agent_node, agent=context_aware_doc_writer_agent, name="DocWriter"
)

note_taking_agent = create_react_agent(llm,tools=[create_outline, read_document])
context_aware_note_taking_agent = prelude | note_taking_agent
note_taking_node = functools.partial(
    agent_node, agent=context_aware_note_taking_agent, name="NoteTaker"
)

chart_generating_agent = create_react_agent(llm, tools=[read_document, python_repl])
context_aware_chart_generating_agent = prelude | chart_generating_agent
chart_generating_node = functools.partial(
    agent_node, agent=context_aware_note_taking_agent, name="ChartGenerator"
)

doc_writing_supervisor = create_team_supervisor(
    llm,
    "You are a supervisor tasked with managing a conversation between the"
    " following workers:  {team_members}. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH.",
    ["DocWriter", "NoteTaker", "ChartGenerator"],
)

# %% [markdown]
# With the objects themselves created, we can form the graph.

# %%
# Create the graph here:
# Note that we have unrolled the loop for the sake of this doc
authoring_graph = StateGraph(DocWritingState)
authoring_graph.add_node("DocWriter", doc_writing_node)
authoring_graph.add_node("NoteTaker", note_taking_node)
authoring_graph.add_node("ChartGenerator", chart_generating_node)
authoring_graph.add_node("supervisor", doc_writing_supervisor)

# Add the edges that always occur
authoring_graph.add_edge("DocWriter", "supervisor")
authoring_graph.add_edge("NoteTaker", "supervisor")
authoring_graph.add_edge("ChartGenerator", "supervisor")

# Add the edges where routing applies
authoring_graph.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {
        "DocWriter": "DocWriter",
        "NoteTaker": "NoteTaker",
        "ChartGenerator": "ChartGenerator",
        "FINISH": END,
    },
)

authoring_graph.add_edge(START, "supervisor")
chain = authoring_graph.compile()


# The following functions interoperate between the top level graph state
# and the state of the research sub-graph
# this makes it so that the states of each graph don't get intermixed
def enter_chain(message: str, members: List[str]):
    results = {
        "messages": [HumanMessage(content=message)],
        "team_members": ", ".join(members),
    }
    return results


# We reuse the enter/exit functions to wrap the graph
authoring_chain = (
    functools.partial(enter_chain, members=authoring_graph.nodes)
    | authoring_graph.compile()
)

# %%
from IPython.display import Image, display

display(Image(chain.get_graph().draw_mermaid_png()))

# %%
for s in authoring_chain.stream(
    "Write an outline for poem and then write the poem to disk.",
    {"recursion_limit": 100},
):
    if "__end__" not in s:
        print(s)
        print("---")
# Out:
# {'supervisor': {'next': 'NoteTaker'}}
# ---
# {'NoteTaker': {'messages': [HumanMessage(content='The poem "Seasons of Life" has been successfully written and saved to the file `seasons_of_life_poem.txt`.\n\nIs there anything else you would like to do?', additional_kwargs={}, response_metadata={}, name='NoteTaker')]}}
# ---
# {'supervisor': {'next': 'DocWriter'}}
# ---
# {'DocWriter': {'messages': [HumanMessage(content='The poem "Seasons of Life" has been successfully written and saved to the file `seasons_of_life_poem.txt`.\n\nIs there anything else you would like to do?', additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'NoteTaker'}}
# ---
# {'NoteTaker': {'messages': [HumanMessage(content='The outline for the poem "Seasons of Life" has been successfully created and saved to `seasons_of_life_outline.txt`. Additionally, the poem has been written and saved to `seasons_of_life_poem.txt`. Here is the poem based on the provided outline:\n\n### Seasons of Life\n\n#### Introduction: The Cycle of Seasons\nIn the grand symphony of life, seasons play their part,  \nEach one a chapter, a role in the heart.\n\n#### Spring: Birth and New Beginnings\nSpring arrives with whispers of gentle breeze,  \nBuds bloom, and life begins to tease.  \nA canvas of green, a tale of rebirth,  \nThe promise of potential, the gift of Earth.\n\n#### Summer: Growth and Vitality\nSummer blazes with the sun\'s warm embrace,  \nDays of endless light, a golden chase.  \nLife in full bloom, vibrant and strong,  \nA symphony of growth, a joyous song.\n\n#### Autumn: Change and Maturity\nAutumn paints the world in hues of gold,  \nStories of change and maturity told.  \nLeaves fall gently, a reminder of time,  \nThe beauty of transition, nature\'s rhyme.\n\n#### Winter: Reflection and Endings\nWinter arrives with a quiet grace,  \nA time for reflection, a slower pace.  \nThe world rests under a blanket of white,  \nEndings and beginnings, in the still of the night.\n\n#### Conclusion: Continuity and Hope\nSeasons turn, an eternal dance,  \nLife\'s continuity, a second chance.  \nIn every ending, a new beginning lies,  \nA cycle unbroken, beneath the skies.\n\nBoth the outline and the poem are now saved. Is there anything else you would like to do?', additional_kwargs={}, response_metadata={}, name='NoteTaker')]}}
# ---
# {'supervisor': {'next': 'FINISH'}}
# ---

# %% [markdown]
# ## Add chatbot to a hierarchical team
# 有时候通用知识可以回答，不一定非要scratch。

# %%
from langchain_openai import AzureChatOpenAI

llm = AzureChatOpenAI(
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)
class ChatState(TypedDict):
    messages: Annotated[List[BaseMessage], operator.add]
    # next: str
    

def chatbot(state: ChatState):
    return {"messages": [llm.invoke(state["messages"])]}


chat_graph = StateGraph(ChatState)
chat_graph.add_node("chatbot", chatbot)
chat_graph.add_edge(START, "chatbot")
chat_graph.add_edge("chatbot", END)
chat_chian = chat_graph.compile()
# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.

# %%
from IPython.display import Image, display

display(Image(chat_chian.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# ## Add Layers
#
# In this design, we are enforcing a top-down planning policy. We've created two graphs already, but we have to decide how to route work between the two.
#
# We'll create a _third_ graph to orchestrate the previous two, and add some connectors to define how this top-level state is shared between the different graphs.

# %%
from langchain_core.messages import BaseMessage


llm = AzureChatOpenAI(
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)
supervisor_node = create_team_supervisor(
    llm,
    "You are a supervisor tasked with managing a conversation between the"
    " following teams: {team_members}. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH.",
    ["chatbot","ResearchTeam", "PaperWritingTeam"],
)

# %%
# Top-level graph state
class State(TypedDict):
    messages: Annotated[List[BaseMessage], operator.add]
    next: str


def get_last_message(state: State) -> str:
    return state["messages"][-1].content


def join_graph(response: dict):
    return {"messages": [response["messages"][-1]]}


# Define the graph.
super_graph = StateGraph(State)
# add chatbot
super_graph.add_node("chatbot", get_last_message|chat_chian|join_graph)
# First add the nodes, which will do the work
super_graph.add_node("ResearchTeam", get_last_message | research_chain | join_graph)
super_graph.add_node(
    "PaperWritingTeam", get_last_message | authoring_chain | join_graph
)

super_graph.add_node("supervisor", supervisor_node)

# Define the graph connections, which controls how the logic
# propagates through the program
super_graph.add_edge("chatbot", "supervisor")
super_graph.add_edge("ResearchTeam", "supervisor")
super_graph.add_edge("PaperWritingTeam", "supervisor")


super_graph.add_conditional_edges(
    "supervisor",
    lambda x: x["next"],
    {
        "PaperWritingTeam": "PaperWritingTeam",
        "ResearchTeam": "ResearchTeam",
        "chatbot": "chatbot",
        "FINISH": END,
    },
)
super_graph.add_edge(START, "supervisor")



super_graph = super_graph.compile()

# %%
from IPython.display import Image, display

display(Image(super_graph.get_graph().draw_mermaid_png()))

# %%
for s in super_graph.stream(
    {
        "messages": [
            HumanMessage(
                content="Write a brief research report about the great wall. Include a chart."
            )
        ],
    },
    {"recursion_limit": 150},
):
    if "__end__" not in s:
        print(s)
        print("---")
# Out:
# {'supervisor': {'next': 'ResearchTeam'}}
# ---
# {'ResearchTeam': {'messages': [HumanMessage(content='## The Great Wall of China: A Brief Research Report\n\n### Introduction\nThe Great Wall of China is one of the most iconic and monumental structures in human history. Spanning thousands of miles, this ancient fortification has served various purposes over the centuries, from defense to immigration control. This report delves into the history, significance, construction, and intriguing facts about the Great Wall of China.\n\n### History\nThe history of the Great Wall of China dates back to the Spring and Autumn Period (770-476 BCE) and the Warring States Period (475-221 BCE), when various Chinese states built walls to defend their territories. The first unified wall, often referred to as the "first Great Wall," was constructed under Emperor Qin Shihuang of the Qin Dynasty (221-206 BCE). This wall was intended to protect against invasions from northern tribes like the Mongols.\n\nThe wall underwent significant expansions and enhancements during the Ming Dynasty (1368-1644 CE), which added distinctive watchtowers and expanded its length and width. The Ming Dynasty\'s contributions largely constitute the wall as we know it today.\n\n### Significance\nThe Great Wall of China holds immense historical and cultural significance. It served as a formidable barrier protecting China\'s economic development and cultural progress. The wall safeguarded trading routes such as the Silk Road and secured the transmission of information and transportation in northern China. It also symbolized the enduring spirit and ingenuity of Chinese civilization.\n\n### Construction\nThe construction of the Great Wall was a colossal undertaking that spanned several dynasties and centuries. Various materials were used, including stone, brick, soil, sand, reed, and wood. The labor force comprised soldiers, peasants, and prisoners. The wall was built across diverse terrains, from deserts to mountains, making its construction an engineering marvel. Different sections of the wall were constructed using local materials, and complex techniques were employed to ensure its stability and longevity.\n\n### Intriguing Facts\n1. **Length**: The Great Wall stretches approximately 13,171 miles (21,196 km) from the Jiayuguan Pass in the west to the Hushan Mountains in the east.\n2. **Visibility from Space**: Contrary to popular belief, the Great Wall is not visible from space with the naked eye.\n3. **Ming Dynasty Contributions**: The current structure is primarily the work of the Ming Dynasty.\n4. **Cultural Symbol**: The Great Wall is a symbol of Chinese strength and resilience, often referred to as the "Earth Dragon."\n\n### Chart: Timeline of the Great Wall\'s Construction\n\n| Period                | Dynasty/State                | Key Contributions                                           |\n|-----------------------|------------------------------|-------------------------------------------------------------|\n| Spring and Autumn     | Various States               | Initial defensive walls built by individual states          |\n| Warring States Period | Various States               | Continued construction of state-specific walls              |\n| Qin Dynasty           | Qin Shihuang                 | Unification of northern walls to form the first Great Wall  |\n| Han Dynasty           | Han                          | Expansion of the wall to protect Silk Road trade routes     |\n| Sui Dynasty           | Sui                          | Extensive rebuilding of the wall                            |\n| Tang Dynasty          | Tang                         | Minimal construction due to superior power over neighbors   |\n| Song Dynasty          | Song                         | Construction to defend against northern invasions           |\n| Ming Dynasty          | Ming                         | Major enhancements, including watchtowers and expansions    |\n| Modern Era            | People\'s Republic of China   | Restorati ...
# ---
# {'supervisor': {'next': 'ResearchTeam'}}
# ---
# {'ResearchTeam': {'messages': [HumanMessage(content='## The Great Wall of China: A Brief Research Report\n\n### Introduction\nThe Great Wall of China is one of the most iconic and monumental structures in human history. Spanning thousands of miles, this ancient fortification has served various purposes over the centuries, from defense to immigration control. This report delves into the history, significance, construction, and intriguing facts about the Great Wall of China.\n\n### History\nThe history of the Great Wall of China dates back to the Spring and Autumn Period (770-476 BCE) and the Warring States Period (475-221 BCE), when various Chinese states built walls to defend their territories. The first unified wall, often referred to as the "first Great Wall," was constructed under Emperor Qin Shihuang of the Qin Dynasty (221-206 BCE). This wall was intended to protect against invasions from northern tribes like the Mongols.\n\nThe wall underwent significant expansions and enhancements during the Ming Dynasty (1368-1644 CE), which added distinctive watchtowers and expanded its length and width. The Ming Dynasty\'s contributions largely constitute the wall as we know it today.\n\nSources:\n- [China Highlights](https://www.chinahighlights.com/greatwall/history/)\n- [World History Encyclopedia](https://www.worldhistory.org/Great_Wall_of_China/)\n- [National Geographic](https://www.nationalgeographic.org/encyclopedia/great-wall-china/)\n- [Britannica](https://www.britannica.com/topic/Great-Wall-of-China)\n- [History](https://www.history.com/topics/ancient-china/great-wall-of-china)\n\n### Significance\nThe Great Wall of China holds immense historical and cultural significance. It served as a formidable barrier protecting China\'s economic development and cultural progress. The wall safeguarded trading routes such as the Silk Road and secured the transmission of information and transportation in northern China. It also symbolized the enduring spirit and ingenuity of Chinese civilization.\n\nSources:\n- [UNESCO World Heritage](https://unescoworld.com/heritage/the-great-wall/)\n- [China Highlights](https://www.chinahighlights.com/greatwall/great-wall-importance.htm)\n- [World History Encyclopedia](https://www.worldhistory.org/Great_Wall_of_China/)\n- [National Geographic](https://www.nationalgeographic.org/encyclopedia/great-wall-china/)\n\n### Construction\nThe construction of the Great Wall was a colossal undertaking that spanned several dynasties and centuries. Various materials were used, including stone, brick, soil, sand, reed, and wood. The labor force comprised soldiers, peasants, and prisoners. The wall was built across diverse terrains, from deserts to mountains, making its construction an engineering marvel. Different sections of the wall were constructed using local materials, and complex techniques were employed to ensure its stability and longevity.\n\nSources:\n- [Parametric Architecture](https://parametric-architecture.com/the-great-wall-of-china/)\n- [China Highlights](https://www.chinahighlights.com/greatwall/fact/how-the-great-wall-was-built.htm)\n- [History](https://www.history.com/topics/ancient-china/great-wall-of-china)\n- [Wikipedia](https://en.wikipedia.org/wiki/Great_Wall_of_China)\n- [Britannica](https://www.britannica.com/topic/Great-Wall-of-China)\n\n### Intriguing Facts\n1. **Length**: The Great Wall stretches approximately 13,171 miles (21,196 km) from the Jiayuguan Pass in the west to the Hushan Mountains in the east.\n2. **Visibility from Space**: Contrary to popular belief, the Great Wall is not visible from space with the naked eye.\n3. **Ming Dynasty Contributions**: The current structure is primarily the work of the Ming Dynasty.\n4. **Cultural Symbol**: The Great Wall is a symbol of Chinese strength and resilience, often referred to as the "Earth Dragon."\n\nSources:\n- [China Travel](https://www.chinatravel.com/great-wall-of-china/fun-facts)\n- [Have Fun with History](https://www.havefunwithhi ...
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content='The research report on "The Great Wall of China" has been successfully saved as `Great_Wall_of_China_Report.txt`. If you need any further assistance or modifications, feel free to let me know!', additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content='It seems there was a repetition in your request. The outline for the research report has been successfully saved. If you need any further assistance or modifications, please let me know!', additional_kwargs={}, response_metadata={}, name='ChartGenerator')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="It seems like there was some confusion earlier. Let's focus on creating the outline for your research report. Please provide the topic of your research and any specific sections you want to include. If you're unsure, I can suggest a generic structure for a research report.", additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="Let's go ahead and create an outline for your research report. Please provide the topic of your research. If you are satisfied with the generic structure below, we can use it as a base and customize it according to your needs.\n\nHere’s the generic structure for a research report:\n\n1. **Title Page**\n2. **Abstract**\n3. **Introduction**\n   - Background Information\n   - Research Problem\n   - Research Objectives\n   - Research Questions\n   - Hypotheses\n4. **Literature Review**\n   - Theoretical Framework\n   - Previous Studies\n   - Gaps in the Literature\n5. **Methodology**\n   - Research Design\n   - Data Collection Methods\n   - Data Analysis Methods\n   - Ethical Considerations\n6. **Results**\n   - Presentation of Data\n   - Analysis of Data\n7. **Discussion**\n   - Interpretation of Results\n   - Implications of Findings\n   - Limitations of the Study\n8. **Conclusion**\n   - Summary of Findings\n   - Recommendations for Future Research\n9. **References**\n10. **Appendices**\n\nPlease provide your research topic and any specific adjustments you want to make. Once I have the details, I'll create the outline document for you.", additional_kwargs={}, response_metadata={}, name='ChartGenerator')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="Great! Let's move ahead with creating the outline for your research report. Please provide the topic of your research. If you're satisfied with the generic structure provided, I'll create the outline document based on it with your specified research topic. If there are any specific adjustments or additional sections you'd like to include, please let me know.\n\nSo, what's the topic of your research?", additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content='The outline for your research report on "The Impact of Climate Change on Coastal Ecosystems" has been created and saved as `Impact_of_Climate_Change_on_Coastal_Ecosystems_Outline.txt`.\n\nWould you like to read the content of the outline or proceed with another task?', additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content='The **Abstract** section has been drafted and saved as `Impact_of_Climate_Change_on_Coastal_Ecosystems_Abstract.txt`.\n\nWould you like to proceed with drafting another section, or do you have another task in mind?', additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content='The full **Methodology** section has been successfully drafted and saved as `Impact_of_Climate_Change_on_Coastal_Ecosystems_Methodology.txt`.\n\nWould you like to proceed with outlining or drafting the next section, such as the **Results** or **Discussion**, or do you have another task in mind?', additional_kwargs={}, response_metadata={}, name='NoteTaker')]}}
# ---
# {'supervisor': {'next': 'ResearchTeam'}}
# ---
# {'ResearchTeam': {'messages': [HumanMessage(content='The full **Methodology** section has been successfully drafted and saved as `Impact_of_Climate_Change_on_Coastal_Ecosystems_Methodology.txt`.\n\nWould you like to proceed with outlining or drafting the next section, such as the **Results** or **Discussion**, or do you have another task in mind?', additional_kwargs={}, response_metadata={})]}}
# ---
# {'supervisor': {'next': 'ResearchTeam'}}
# ---
# {'ResearchTeam': {'messages': [HumanMessage(content='The full **Methodology** section has been successfully drafted and saved as `Impact_of_Climate_Change_on_Coastal_Ecosystems_Methodology.txt`.\n\nWould you like to proceed with outlining or drafting the next section, such as the **Results** or **Discussion**, or do you have another task in mind?', additional_kwargs={}, response_metadata={})]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="The draft for the **Interpretation of Data** subsection is comprehensive and insightful. Please proceed with drafting the **Summary of Key Results** subsection.\n\nHere's a draft for the **Summary of Key Results** subsection of the **Analysis of Findings** section:\n\n---\n\n##### Summary of Key Results\n\nThe key results of this study on the impact of climate change on coastal ecosystems are summarized as follows:\n\n1. **Temperature Trends**\n   - The average temperature recorded is 22.5°C, consistent with previous studies.\n   - A positive correlation between temperature and biodiversity index suggests that moderate temperature increases may enhance biodiversity, but extreme variations could be detrimental.\n\n2. **Salinity Levels**\n   - The mean salinity level is 35.0 ppt, aligning with historical data.\n   - Minor fluctuations in salinity levels indicate that coastal ecosystems exhibit resilience within the observed range.\n\n3. **Biodiversity Index**\n   - The biodiversity index averages at 4.2, showing stability over time.\n   - This stability suggests that despite climatic changes, biodiversity levels have remained relatively constant.\n\n4. **Species Population**\n   - The average species count is 150, corroborating with past research.\n   - Stable species populations indicate balanced ecosystems, though certain species may be more susceptible to climate change.\n\n5. **Overall Ecosystem Health**\n   - Coastal ecosystems show gradual changes due to climate change but demonstrate resilience.\n   - Continuous monitoring and adaptive management are crucial to sustaining ecosystem health and biodiversity.\n\nThese key results highlight the importance of maintaining optimal environmental conditions to support the health and diversity of coastal ecosystems. They also underscore the need for targeted conservation efforts and climate adaptation strategies to mitigate the adverse effects of climate change.\n\n---\n\nPlease review the draft and let me know if there are any changes you would like to make. If everything looks good, the **Results** section will be complete.", additional_kwargs={}, response_metadata={}, name='NoteTaker')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="Great! Now that the **Summary of Key Results** subsection has been drafted and saved, would you like to proceed with any other sections or tasks related to the document? If you need modifications or additional sections, please provide the details and I'll get started.", additional_kwargs={}, response_metadata={}, name='NoteTaker')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# {'PaperWritingTeam': {'messages': [HumanMessage(content="The **Introduction** section has been successfully drafted and saved in the document. Would you like to proceed with drafting another section, making modifications, or performing any other tasks related to the document? Let me know how you'd like to continue!", additional_kwargs={}, response_metadata={}, name='DocWriter')]}}
# ---
# {'supervisor': {'next': 'PaperWritingTeam'}}
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:1224, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1218 while loop.tick(
#    1219     input_keys=self.input_channels,
#    1220     interrupt_before=interrupt_before,
#    1221     interrupt_after=interrupt_after,
#    1222     manager=run_manager,
#    1223 ):
# -> 1224     for _ in runner.tick(
#    1225         loop.tasks.values(),
#    1226         timeout=self.step_timeout,
#    1227         retry_policy=self.retry_policy,
#    1228     ):
#    1229         # emit output
#    1230         for o in output():
#
# File ~/.local/lib/python3.11/site-packages/langgraph/pregel/runner.py:60, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy)
#      59 while futures:
# ---> 60     done, _ = concurrent.futures.wait(
#      61         futures,
#      62         return_when=concurrent.futures.FIRST_COMPLETED,
#      63         timeout=(max(0, end_time - time.monotonic()) if end_time else None),
#      64     )
#      65     if not done:
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for s in super_graph.stream(
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     {
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         "messages": [
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>             HumanMessage(
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>                 content="Write a brief research report about the great wall. Include a chart."
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>             )
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         ],
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     },
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     {"recursion_limit": 150},
#      <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> ):
#      <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     if "__end__" not in s:
#      <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/hierarchical_agent_teams.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>         print(s)
#
# File ~/.local/lib/python3.11/site-packages/langgraph/pregel/__init__.py:1193, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1176 # assign defaults
#    1177 (
#    1178     debug,
#    1179     stream_modes,
#    (...)
#    1190     debug=debug,
#    1191 )
# -> 1193 with SyncPregelLoop(
#    1194     input,
#    1195     stream=stream.append,
#    1196     config=config,
#    1197     store=self.store,
#    1198     checkpointer=checkpointer,
#    1199     nodes=self.nodes,
#    1200     specs=self.channels,
#    1201     output_keys=output_keys,
#    1202     stream_keys=self.stream_channels_asis,
#    1203     debug=debug,
#    1204 ) as loop:
#    1205     # create runner
#    1206     runner = PregelRunner(
#    1207         submit=loop.submit,
#    1208         put_writes=loop.put_writes,
#    1209     )
#    1210     # enable subgraph streaming
#
# File ~/.local/lib/python3.11/site-packages/langgraph/pregel/loop.py:708, in SyncPregelLoop.__exit__(self, exc_type, exc_value, traceback)
#     701 def __exit__(
#     702     self,
#     703     exc_type: Optional[Type[BaseException]],
#    (...)
#     706 ) -> Optional[bool]:
#     707     # unwind stack
# --> 708     return self.stack.__exit__(exc_type, exc_value, traceback)
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/contextlib.py:586, in ExitStack.__exit__(self, *exc_details)
#     582 try:
#     583     # bare "raise exc_details[1]" replaces our carefully
#     584     # set-up context
#     585     fixed_ctx = exc_details[1].__context__
# --> 586     raise exc_details[1]
#     587 except BaseException:
#     588     exc_details[1].__context__ = fixed_ctx
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/contextlib.py:571, in ExitStack.__exit__(self, *exc_details)
#     569 assert is_sync
#     570 try:
# --> 571     if cb(*exc_details):
#     572         suppressed_exc = True
#     573         pending_raise = False
#
# File ~/.local/lib/python3.11/site-packages/langgraph/pregel/executor.py:86, in BackgroundExecutor.__exit__(self, exc_type, exc_value, traceback)
#      84 # wait for all tasks to finish
#      85 if tasks := {t for t in self.tasks if not t.done()}:
# ---> 86     concurrent.futures.wait(tasks)
#      87 # shutdown the executor
#      88 self.stack.__exit__(exc_type, exc_value, traceback)
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
for s in super_graph.stream(
    {
        "messages": [
            HumanMessage(
                content="Write a brief research report on the North American sturgeon. Include a chart."
            )
        ],
    },
    {"recursion_limit": 150},
):
    if "__end__" not in s:
        print(s)
        print("---")
# Out:
# {'supervisor': {'next': 'ResearchTeam'}}
# ---
