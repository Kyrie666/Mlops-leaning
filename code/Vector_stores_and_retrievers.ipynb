# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
__import__('pysqlite3')
import sys
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
from dotenv import load_dotenv, find_dotenv
import os
load_dotenv(find_dotenv())



from langchain_openai import AzureChatOpenAI

model = AzureChatOpenAI(

    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
from langchain_chroma import Chroma
# from langchain_openai import OpenAIEmbeddings
from langchain_openai import AzureOpenAIEmbeddings

vectorstore = Chroma.from_documents(
    documents,
    embedding=AzureOpenAIEmbeddings(),
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # from langchain_openai import OpenAIEmbeddings
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from langchain_openai import AzureOpenAIEmbeddings
# ----> <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> vectorstore = Chroma.from_documents(
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     documents,
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     embedding=AzureOpenAIEmbeddings(),
#       <a href='vscode-notebook-cell://icube%2Bicube/cloudide/workspace/Python/langchina/Vector_tores_and_retrievers.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> )
#
# File ~/.local/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:1128, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#    1126 texts = [doc.page_content for doc in documents]
#    1127 metadatas = [doc.metadata for doc in documents]
# -> 1128 return cls.from_texts(
#    1129     texts=texts,
#    1130     embedding=embedding,
#    1131     metadatas=metadatas,
#    1132     ids=ids,
#    1133     collection_name=collection_name,
#    1134     persist_directory=persist_directory,
#    1135     client_settings=client_settings,
#    1136     client=client,
#    1137     collection_metadata=collection_metadata,
#    1138     **kwargs,
#    1139 )
#
# File ~/.local/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:1089, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#    1083         chroma_collection.add_texts(
#    1084             texts=batch[3] if batch[3] else [],
#    1085             metadatas=batch[2] if batch[2] else None,  # type: ignore
#    1086             ids=batch[0],
#    1087         )
#    1088 else:
# -> 1089     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#    1090 return chroma_collection
#
# File ~/.local/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:508, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     506 texts = list(texts)
#     507 if self._embedding_function is not None:
# --> 508     embeddings = self._embedding_function.embed_documents(texts)
#     509 if metadatas:
#     510     # fill metadatas with empty dicts if somebody
#     511     # did not specify metadata for all texts
#     512     length_diff = len(texts) - len(metadatas)
#
# File ~/.local/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:616, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     613 # NOTE: to keep things simple, we assume the list may contain texts longer
#     614 #       than the maximum context and use length-safe embedding function.
#     615 engine = cast(str, self.deployment)
# --> 616 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File ~/.local/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:514, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     512 batched_embeddings: List[List[float]] = []
#     513 for i in _iter:
# --> 514     response = self.client.create(
#     515         input=tokens[i : i + _chunk_size], **self._invocation_params
#     516     )
#     517     if not isinstance(response, dict):
#     518         response = response.model_dump()
#
# File ~/.local/lib/python3.11/site-packages/openai/resources/embeddings.py:125, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     119         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     120             base64.b64decode(data), dtype="float32"
#     121         ).tolist()
#     123     return obj
# --> 125 return self._post(
#     126     "/embeddings",
#     127     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     128     options=make_request_options(
#     129         extra_headers=extra_headers,
#     130         extra_query=extra_query,
#     131         extra_body=extra_body,
#     132         timeout=timeout,
#     133         post_parser=parser,
#     134     ),
#     135     cast_to=CreateEmbeddingResponse,
#     136 )
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# NotFoundError: Error code: 404 - {'error': {'code': 'DeploymentNotFound', 'message': 'The API deployment for this resource does not exist. If you created the deployment within the last 5 minutes, please wait a moment and try again.'}}

# %%
# %pip install pysqlite3-binary
# Out:
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple
# Collecting pysqlite3-binary
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/a3/0e/1cacce3309e5e70e65e9348a27564bb07f9ae703fa74d25054a96fbf6e9e/pysqlite3_binary-0.5.3.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 21.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pysqlite3-binary
# Successfully installed pysqlite3-binary-0.5.3.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain langchain-chroma langchain-openai
# Out:
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple
# Requirement already satisfied: langchain in /home/cloudide/.local/lib/python3.11/site-packages (0.2.16)
# Collecting langchain-chroma
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/65/22/fa0a518618d769dacc732cf3a623debb04720949e1a5f26d02756c19449f/langchain_chroma-0.1.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: langchain-openai in /home/cloudide/.local/lib/python3.11/site-packages (0.1.23)
# Requirement already satisfied: PyYAML>=5.3 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (0.2.39)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (0.1.118)
# Requirement already satisfied: numpy<2,>=1 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain) (8.5.0)
# Collecting chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 (from langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/3e/c9/d55602e07bb839c578f4698b92db7ea88c1aa92f69d4c86076c1597e451b/chromadb-0.5.3-py3-none-any.whl (559 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: fastapi<1,>=0.95.2 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain-chroma) (0.114.1)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain-openai) (1.44.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/cloudide/.local/lib/python3.11/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/cloudide/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/cloudide/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/cloudide/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/cloudide/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/cloudide/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Collecting build>=1.0.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/91/fd/e4bda6228637ecae5732162b5ac2a5a822e2ba8e546eb4997cde51b231a3/build-1.2.2-py3-none-any.whl (22 kB)
# Collecting chroma-hnswlib==0.7.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/48/0e/068b658a547d6090b969014146321e28dae1411da54b76d081e51a2af22b/chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: uvicorn>=0.18.3 in /home/cloudide/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0
obuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/db/74/a0e0d38622856597dd8e630f2bd793760485eb165708e11b8be1696bbb5a/opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/0a/7f/405c41d4f359121376c9d5117dcf68149b8122d3f6c718996d037bd4d800/opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/b7/7a/4f0063dbb0b6c971568291a8bc19a4ca70d3c185db2d956230dd67429dfc/opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/ad/2e/36097c0a4d0115b8c7e377c90bab7783ac183bc5cb4071308f8959454311/opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (65.5.0)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/6e/52/2da48b35193e39ac53cfb141467d9f259851522d0e8c87153f0ba4205fb1/wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/39/e3/893e8757be2612e6c266d9bb58ad2e3651524b5b40cf56761e985a28b13e/asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/b9/8f/d6718641c14d98a5848c6a24d2376028d292074ffade0702940a4b1dde76/huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Requirement already satisfied: click>=8.0.0 in /home/cloudide/.local/lib/python3.11/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Collecting rich>=10.11.0 (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/b0/11/dadb85e2bd6b1f1ae56669c3e1f0410797f9605d752d68fb47b77f525b31/rich-13.8.1-py3-none-any.whl (241 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/59/23/047a89e66045232fb82c50ae57699e40f70e073ae5ccd53f54e532fbd2a2/httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /home/cloudide/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/46/6d/4caab3a36199ba52b98d519feccfcf48921d7a6649daf14a93c7e77497e9/uvloop-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 40.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/70/eb/82f089c4f44b3171ad87a1b433abb4696f18eb67292909630d886e073abe/watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/f8/4e/ffa2f1aad2da67e483fb7bad6c69f80c786f4e85d1942a39d7b275b084ed/websockets-13.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/a4/07/14f8ad37f2d12a5ce41206c21820d8cb6561b728e51fad4530dff0552a67/cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/77/89/bc88a6711935ba795a679ea6ebee07e128050d6382eaa35a0a47c8032bdc/pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: filelock in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.15.4)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/1d/a0/6aaea0c2fbea2f89bfd5db25fb1e3481896a423002ebe4e55288907a97a3/fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/cloudide/pyenv/versions/3.11.1/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.20.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cloudide/.local/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.18.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 27.1 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/c8/f1/d6a797abb14f6283c0ddff96bbdd46937f64122b8c925cab503dd37f8214/pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53726 sha256=3cbd13f227bdb5c646c05457d0c9f152ded2a912158eb42416e734b45462a3ce
#   Stored in directory: /home/cloudide/.cache/pip/wheels/aa/b7/3e/4a9e2600c7265b2170e689f2a9658b498573cf4157d5e1888f
# Successfully built pypika
# Installing collected packages: pypika, mpmath, monotonic, mmh3, flatbuffers, wrapt, websockets, websocket-client, uvloop, sympy, pyasn1, protobuf, overrides, opentelemetry-util-http, oauthlib, mdurl, importlib-resources, humanfriendly, httptools, grpcio, fsspec, chroma-hnswlib, cachetools, build, bcrypt, backoff, asgiref, watchfiles, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, huggingface-hub, googleapis-common-protos, deprecated, coloredlogs, tokenizers, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, typer, opentelemetry-semantic-conventions, opentelemetry-instrumentation, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# poetry 1.5.1 requires build<0.11.0,>=0.10.0, but you have build 1.2.2 which is incompatible.
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2 cachetools-5.5.0 chroma-hnswlib-0.7.3 chromadb-0.5.3 coloredlogs-15.0.1 deprecated-1.2.14 flatbuffers-24.3.25 fsspec-2024.9.0 google-auth-2.34.0 googleapis-common-protos-1.65.0 grpcio-1.66.1 httptools-0.6.1 huggingface-hub-0.24.6 humanfriendly-10.0 importlib-resources-6.4.5 kubernetes-30.1.0 langchain-chroma-0.1.3 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 oauthlib-3.2.2 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.6.5 protobuf-4.25.4 pyasn1-0.6.1 pyasn1-modules-0.4.1 pypika-0.48.9 requests-oauthlib-2.0.0 rich-13.8.1 rsa-4.9 sympy-1.13.2 tokenizers-0.20.0 typer-0.12.5 uvloop-0.20.0 watchfiles-0.24.0 websocket-client-1.8.0 websockets-13.0.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.
